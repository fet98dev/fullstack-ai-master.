# %% [markdown]
# CLASE PERSONA
# Define una clase Persona con atributos como nombre, edad y profesión.
# Luego, crea varios objetos de esta clase y muestra su información

# %%
class Persona:
    def __init__(self,nombre,edad,profesion):
        self.nombre = nombre
        self.edad = edad
        self.profesion = profesion

la_persona = Persona("Juan","45","Informatico")

print(la_persona.nombre)
print(la_persona.edad)
print(la_persona.profesion)
# Out:
# Juan
# 45
# Informatico

# %% [markdown]
# CALCULADORA BÁSICA
# Crea una clase llamada "Calculadora" con métodos para sumar, restar,
# multiplicar y dividir. Crea objetos de esta clase y realiza algunas operaciones
# básicas.

# %%
class Calculadora:
    def __init__(self,n1,n2):
        self.suma = n1 + n2
        self.resta = n1 - n2
        self.multiplicacion = n1 * n2
        self.division = n1 / n2

calcular = Calculadora(10,2)
print(calcular.suma)
print(calcular.resta)
print(calcular.multiplicacion)
print(calcular.division)
# Out:
# 12
# 8
# 20
# 5.0

# %% [markdown]
# LIBRO
# Crea una clase “Libro” con atributos como título, autor y año de publicación. Luego, crea varios objetos Libro y muestra su información.

# %%
class Libro:
    def __init__(self,titulo,autor,year):
        self.titulo = titulo
        self.autor = autor
        self.year = year

el_quijote = Libro("El quijote","cervantes","1498")
el_hbuscasentido = Libro("El hombre en busca de sentido","Viktor Frank","1945")


print(el_quijote.titulo,el_quijote.autor,el_quijote.year)
print(el_hbuscasentido.titulo,el_hbuscasentido.autor,el_hbuscasentido.year)
# Out:
# El quijote cervantes 1498
# El hombre en busca de sentido Viktor Frank 1945

# %% [markdown]
# RECTÁNGULO
# Crea una clase “Rectangulo” con atributos de longitud y ancho. Implementa un método para calcular el área y el perímetro del rectángulo.

# %%
class Rectangulo:
    def __init__(self,long,anch):
        self.longitud = long
        self.anch = anch
    def calcular_hipotenusa(self):
        #Raiz cuadrada
        return(self.longitud**2 + self.anch**2) ** 0.5
    def calcular_perimetro(self):
        return self.longitud + self.anch + self.calcular_hipotenusa()
    def calcular_area(self):
        return (self.longitud * self.anch) / 2

mi_triangulo = Rectangulo(10,2)
print(f"Perimetro: {mi_triangulo.calcular_perimetro()}")
print(f"Perimetro: {mi_triangulo.calcular_area()}")
# Out:
# Perimetro: 22.19803902718557
# Perimetro: 10.0
